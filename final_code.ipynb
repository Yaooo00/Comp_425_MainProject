# %%
import torch
import sys
print("Python Version:", sys.version)
print("PyTorch Version:", torch.__version__)
print("CUDA Version:", torch.version.cuda)
print("CUDA Can Use Or Not:", torch.cuda.is_available())
# Out:
# Python Version: 3.8.20 (default, Oct  3 2024, 15:19:54) [MSC v.1929 64 bit (AMD64)]
# PyTorch Version: 1.13.1
# CUDA Version: 11.7
# CUDA Can Use Or Not: True

# %%
! pip install -U openmim

! mim install mmengine

! mim install "mmcv>=2.0.0rc4,<2.2.0"

! mim install "mmdet>=3.0.0"
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ---------------------------------------- 10.8/10.8 MB 75.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 1.8/1.8 MB 95.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/953.1 kB ? eta -:--:--
#    --------------------------------------- 953.1/953.1 kB 46.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ---------------------------------------- 3.2/3.2 MB 62.7 MB/s eta 0:00:00
# ...

# %%
! git clone https://github.com/open-mmlab/mmdetection3d.git

# %cd mmdetection3d

! pip install -r requirements/build.txt

! pip install -r requirements/runtime.txt

! pip install -v -e .
# Out:
# d:\1.Concordia University\2025 Winter\COMP 425\Project\mmdetection3d\mmdetection3d
# Cloning into 'mmdetection3d'...
# ...
# Using pip 24.2 from D:\anaconda3\envs\COMP_425_Project\lib\site-packages\pip (python 3.8)
# Obtaining file:///D:/1.Concordia%20University/2025%20Winter/COMP%20425/Project/mmdetection3d/mmdetection3d
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Attempting uninstall: mmdet3d
#     Found existing installation: mmdet3d 1.4.0
#     Uninstalling mmdet3d-1.4.0:
#       Removing file or directory d:\anaconda3\envs\comp_425_project\lib\site-packages\mmdet3d.egg-link
#       Removing pth entries from d:\anaconda3\envs\comp_425_project\lib\site-packages\easy-install.pth:
#       Removing entry: d:\1.concordia university\2025 winter\comp 425\project\mmdetection3d
#       Successfully uninstalled mmdet3d-1.4.0
#   Running setup.py develop for mmdet3d
# ...
#   Running command python setup.py egg_info
#   running egg_info
# ...

# %%
! mim download mmdet3d --config pointpillars_hv_secfpn_8xb6-160e_kitti-3d-car --dest .
# Out:
# processing pointpillars_hv_secfpn_8xb6-160e_kitti-3d-car...
# downloading ---------------------------------------- 0.0/18.4 MiB ? eta -:--:--
# downloading --------------------------------- 0.2/18.4 MiB 3.8 MB/s eta 0:00:06
# downloading  -------------------------------- 0.4/18.4 MiB 4.8 MB/s eta 0:00:04
# downloading - ------------------------------- 0.6/18.4 MiB 5.1 MB/s eta 0:00:04
# downloading - ------------------------------- 0.9/18.4 MiB 5.5 MB/s eta 0:00:04
# downloading -- ------------------------------ 1.4/18.4 MiB 7.3 MB/s eta 0:00:03
# downloading --- ----------------------------- 1.9/18.4 MiB 9.3 MB/s eta 0:00:02
# downloading ---- --------------------------- 2.6/18.4 MiB 13.1 MB/s eta 0:00:02
# downloading ----- -------------------------- 3.0/18.4 MiB 10.9 MB/s eta 0:00:02
# downloading ------ ------------------------- 3.5/18.4 MiB 10.9 MB/s eta 0:00:02
# downloading ------- ------------------------ 4.2/18.4 MiB 16.2 MB/s eta 0:00:01
# ...

# %%
! mv /content/pointpillars_hv_secfpn_8xb6-160e_kitti-3d-car.py /content/mmdetection3d/
! mv /content/hv_pointpillars_secfpn_6x8_160e_kitti-3d-car_20220331_134606-d42d15ed.pth /content/mmdetection3d/
# Out:
# 'mv' is not recognized as an internal or external command,
# operable program or batch file.
# 'mv' is not recognized as an internal or external command,
# operable program or batch file.

# %%
! python demo/pcd_demo.py demo/data/kitti/000008.bin pointpillars_hv_secfpn_8xb6-160e_kitti-3d-car.py hv_pointpillars_secfpn_6x8_160e_kitti-3d-car_20220331_134606-d42d15ed.pth --show
# Out:
# 03/17 01:51:13 - mmengine - WARNING - Display device not found. `--show` is forced to False
# Loads checkpoint by local backend from path: hv_pointpillars_secfpn_6x8_160e_kitti-3d-car_20220331_134606-d42d15ed.pth
# 03/17 01:51:17 - mmengine - WARNING - Failed to search registry with scope "mmdet3d" in the "function" registry tree. As a workaround, the current "function" registry in "mmengine" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmdet3d" is a correct scope, or whether the registry is initialized.
#
# Inference ----------------------------------------
# Inference ----------------------------------------
# Inference ----------------------------------------
# Inference ----------------------------------------
# Inference ----------------------------------------
# Inference ----------------------------------------
# Inference ----------------------------------------
# ...
